# %%
import pandas as pd
import numpy as np
import geopy
from geopy.geocoders import Nominatim
import matplotlib.pyplot as plt

# %%
reader = pd.read_csv(r'/Users/kamil/Documents/data_mining/measurements.csv', iterator=True)

# %%
df = reader.get_chunk(100000)

# %%
df.head(30)
# Out:
#                  Captured Time   Latitude   Longitude   Value     Unit  \
# 0          2022-03-19 01:58:57  42.434700  -87.901200    13.0      cpm
# 1   2022-03-19 01:59:53.317925  39.753929 -104.959059    16.0      cpm
# 2          2022-03-19 01:59:33  37.637260  139.660360 -1000.0   status
# 3          2022-03-19 01:59:32  37.637260  139.660360     0.0      cpm
# 4      2022-03-19 01:59:31.332  53.864000   -3.047000    21.0      cpm
# 5          2022-03-19 01:59:31  37.637260  139.660360    37.0      cpm
# 6          2022-03-19 01:59:20  42.565000  -70.783000    26.0   status
# 7          2022-03-19 01:59:20  37.496139  140.986419    18.1   status
# 8          2022-03-19 01:59:20  42.565000  -70.783000    13.0      cpm
# 9          2022-03-19 01:59:19  42.565000  -70.783000    24.0      cpm
# 10     2022-03-19 01:59:19.611  37.442836 -122.128094    29.0      cpm
# 11     2022-03-19 01:59:19.602  37.442836 -122.128094    12.0      cpm
# ...

# %%
df.drop(labels=['Radiation','Longitude','Latitude','Captured Time','Location Name','Device ID','MD5Sum','Surface','Uploaded Time','Loader ID'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Value     float64
# Unit       object
# Height    float64
# dtype: object

# %%
df['Unit'].unique()
# Out:
# array(['cpm', 'status', 'celcius', 'PM10 ug/m3', 'PM2.5 ug/m3', '211',
#        'usv'], dtype=object)

# %%
df = df.loc[df['Unit'] == 'cpm']

# %%
df['Unit'].unique()
# Out:
# array(['cpm'], dtype=object)

# %%
df = df.reset_index(drop=True)
df
# Out:
#        Value Unit  Height
# 0       13.0  cpm     NaN
# 1       16.0  cpm     NaN
# 2        0.0  cpm    60.0
# 3       21.0  cpm     NaN
# 4       37.0  cpm    60.0
# ...      ...  ...     ...
# 75155   25.0  cpm     NaN
# 75156   21.0  cpm     NaN
# 75157   19.3  cpm     NaN
# 75158   66.0  cpm     NaN
# 75159   28.0  cpm     NaN
#
# [75160 rows x 3 columns]

# %%
# result = pd.DataFrame()
# df = pd.read_csv(r'/Users/kamil/Documents/data_mining/measurements.csv', chunksize=1000000)
# for chunk in df:
#     chunk.dropna(subset=['Height','Value'], axis=0, inplace=True)
#     chunk.drop(labels=['Radiation','Longitude','Latitude','Captured Time','Location Name','Device ID','MD5Sum','Surface','Uploaded Time','Loader ID'], axis=1)
#     result = pd.concat([result,chunk])
# del df, chunk
# result = result.reset_index(drop=True)

# %%
def getRawLocation(df):
    locator = Nominatim(user_agent='myGeocoder')
    coordinates = df['Latitude'].apply(str)+ ", " + df['Longitude'].apply(str)
    return coordinates

def

# %%
locator = Nominatim(user_agent='myGeocoder')
coordinates = df['Latitude'].apply(str)+ ", " + df['Longitude'].apply(str)
coordinates
location = locator.reverse(coordinates[0])
location.raw
# Out:
# {'place_id': 319086322,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 21838508,
#  'lat': '42.43469181061767',
#  'lon': '-87.901223781161',
#  'display_name': '39408, North Winchester Road, Wadsworth, Lake County, Illinois, 60083, United States',
#  'address': {'house_number': '39408',
#   'road': 'North Winchester Road',
#   'village': 'Wadsworth',
#   'county': 'Lake County',
#   'state': 'Illinois',
#   'postcode': '60083',
#   'country': 'United States',
#   'country_code': 'us'},
#  'boundingbox': ['42.434641810618',
#   '42.434741810618',
#   '-87.901273781161',
#   '-87.901173781161']}
